# %%
import pandas as pd

from variables import csv_list

print(csv_list)
for csv in csv_list:
    csv = pd.read_csv(csv)
    print(csv['ciudad'].unique())
    display(csv.info(), csv.head())
# Out:
# ['data/clima_donostia.csv', 'data/clima_bilbo.csv', 'data/clima_baiona.csv', 'data/clima_iruna.csv', 'data/clima_gasteiz.csv', 'data/clima_arrasate.csv', 'data/clima_maule.csv']
# <StringArray>
# ['Donostia']
# Length: 1, dtype: str
# <class 'pandas.DataFrame'>
# RangeIndex: 31412 entries, 0 to 31411
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   time                 31412 non-null  str
#  1   temperature_2m_mean  31411 non-null  float64
#  2   temperature_2m_min   31412 non-null  float64
#  3   temperature_2m_max   31412 non-null  float64
#  4   precipitation_sum    31411 non-null  float64
#  5   wind_speed_10m_max   31412 non-null  float64
#  6   ciudad               31412 non-null  str
#  7   año                  31412 non-null  int64
#  8   mes                  31412 non-null  int64
# dtypes: float64(5), int64(2), str(2)
# memory usage: 2.2 MB
# None
# ...
